# %%
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from IPython.display import SVG, display
from keras.utils.vis_utils import model_to_dot
from keras.layers import Input
from keras.models import Model, Sequential
from keras.layers.core import Reshape, Dense, Dropout, Flatten
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D, UpSampling2D, MaxPooling2D
from keras.datasets import mnist
from keras.optimizers import Adam
from keras import backend as K
from keras import initializers
import cv2
import os
import pandas as pd
from keras.utils import to_categorical
from keras.callbacks import TensorBoard, ModelCheckpoint
from keras.preprocessing.image import load_img
import numpy as np
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Using TensorFlow backend.

# %%
filePath = "img_align_celeba/"
inputData = os.listdir(filePath)
img_shape = (64, 64, 3)

def datagen(batchSize,filesList):
    while(True):
        files = np.random.choice(filesList,batchSize,replace=False)
        X_train = []
        for file in files:
            image = cv2.imread(filePath + "/" + file)
#             print(np.array(image).min(),np.array(image).max())
#             print(np.array(image).shape)
#             plt.imshow(image)
            image = cv2.resize(image,(64,64),interpolation = cv2.INTER_CUBIC)
            image = image / 255.0
            X_train.append(image)
        X_train = np.array(X_train)
        yield X_train
        
def discDatagen(batchSize,filesList):
    while(True):
        files = np.random.choice(filesList,batchSize,replace=False)
        X_train, y = [],[]
        for file in files:
            image = cv2.imread(filePath + "/" + file)
#             print(np.array(image).min(),np.array(image).max())
#             print(np.array(image).shape)
#             plt.imshow(image)
            image = cv2.resize(image,(64,64),interpolation = cv2.INTER_CUBIC)
            blurImage = cv2.blur(image,ksize=(8,8))
#             fig = plt.figure(figsize=(6,3))
#             ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
#             ax.imshow(image[:,:,::-1])
#             ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
#             ax.imshow(blurImage[:,:,::-1])
            image = image / 255.0
            blurImage = blurImage / 255.0
            X_train.append(image)
            y.append(0) # for real image
            X_train.append(blurImage)
            y.append(1) # for blurr/fake image
        X_train = np.array(X_train)
        Y_train = to_categorical(y,num_classes=2)
        yield X_train, Y_train
        
randomDim = 100
batchSize = 10
epochs = 1

# %%
discDatagenObj = discDatagen(batchSize,inputData)
for i in range(1):
    x,y = next(discDatagenObj)
#     print(x.shape)
#     print(y)
    fig = plt.figure(figsize=(6,3))
    ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
    ax.imshow(x[0][:,:,::-1])
    ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
    ax.imshow(x[0+1][:,:,::-1])
#     print(x[0][:,:,::-1].shape)

# %%
np.random.seed(1000)

# %% [markdown]
# # Optimizer

# %%
adam = Adam(lr=0.0002, beta_1=0.5)

# %% [markdown]
# # Generator

# %%
generator = Sequential(name='Generator')
generator.add(Dense(128*4*4, input_dim=randomDim,name='GeneratorInput', activation='relu'))
# generator.add(LeakyReLU(0.2))
generator.add(Reshape((4, 4, 128)))

generator.add(UpSampling2D(size=(2, 2)))
generator.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu'))
# generator.add(LeakyReLU(0.2))

generator.add(UpSampling2D(size=(2, 2)))
generator.add(Conv2D(256, kernel_size=(3, 3), padding='same', activation='relu'))


generator.add(UpSampling2D(size=(2, 2)))
generator.add(Conv2D(512, kernel_size=(3, 3), padding='same', activation='relu'))
# generator.add(LeakyReLU(0.2))

generator.add(UpSampling2D(size=(2, 2)))
generator.add(Conv2D(3, kernel_size=(3, 3), padding='same', activation='sigmoid',name='Generator'))
generator.compile(loss='binary_crossentropy', optimizer='sgd', metrics = ['accuracy'])
generator.summary()
display(SVG(model_to_dot(generator,show_layer_names=True,show_shapes=True).create(prog='dot', format='svg')))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# GeneratorInput (Dense)       (None, 2048)              206848
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4, 4, 128)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 512)       1180160
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 64, 64, 512)       0
# _________________________________________________________________
# Generator (Conv2D)           (None, 64, 64, 3)         13827
# =================================================================
# Total params: 1,843,587
# Trainable params: 1,843,587
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Discriminator

# %%
# Discriminator
discriminator = Sequential(name='Discriminator')

discriminator.add(Conv2D(input_shape=(64,64,3),filters=16, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
# discriminator.add(LeakyReLU(0.2))
discriminator.add(Dropout(0.2))
discriminator.add(MaxPooling2D(pool_size=(2,2)))

discriminator.add(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
# discriminator.add(LeakyReLU(0.2))
discriminator.add(Dropout(0.2))
discriminator.add(MaxPooling2D(pool_size=(2,2)))

discriminator.add(Conv2D(256, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
# discriminator.add(LeakyReLU(0.2))
discriminator.add(Dropout(0.2))
discriminator.add(MaxPooling2D(pool_size=(2,2)))

discriminator.add(Conv2D(512, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
# discriminator.add(LeakyReLU(0.2))
discriminator.add(Dropout(0.2))
discriminator.add(MaxPooling2D(pool_size=(2,2)))

discriminator.add(Flatten())
discriminator.add(Dense(2, activation='softmax',name='Discriminator'))
discriminator.compile(loss='categorical_crossentropy', optimizer='sgd', metrics = ['accuracy'])
discriminator.summary()
display(SVG(model_to_dot(discriminator,show_layer_names=True,show_shapes=True).create(prog='dot', format='svg')))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 64, 64, 16)        448
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       18560
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# Discriminator (Dense)        (None, 2)                 16386
# =================================================================
# Total params: 1,510,722
# Trainable params: 1,510,722
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Combined = GAN

# %%
discriminator.trainable = False
ganInput = Input(shape=(randomDim,),name='generator_input')
x = generator(ganInput)
# print(x.shape)
ganOutput = discriminator(x)
gan = Model(inputs=ganInput, outputs=ganOutput, name='GAN')
# gan.layers[1].name = "Generator_Network"
# gan.layers[2].name = "Discriminator_Network"
gan.compile(loss='binary_crossentropy', optimizer='sgd', metrics = ['accuracy'])
gan.summary()
display(SVG(model_to_dot(gan,show_layer_names=True,show_shapes=True).create(prog='dot', format='svg')))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generator_input (InputLayer) (None, 100)               0
# _________________________________________________________________
# Generator (Sequential)       (None, 64, 64, 3)         1843587
# _________________________________________________________________
# Discriminator (Sequential)   (None, 2)                 1510722
# =================================================================
# Total params: 3,354,309
# Trainable params: 1,843,587
# Non-trainable params: 1,510,722
# _________________________________________________________________

# %%
tensorboard = TensorBoard(
  log_dir='log/run16',
  histogram_freq=0,
  batch_size=batchSize,
  write_graph=True,
  write_grads=True
)
tensorboard.set_model(gan)

# %% [markdown]
# # helper functions

# %%
dLosses = []
gLosses = []

def plotLoss(epoch):
    plt.figure(figsize=(10, 8))
    plt.plot(dLosses, label='Discriminitive loss')
    plt.plot(gLosses, label='Generative loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.savefig('images/gan_cnn_64x64_longrun/dcgan_%d_loss_epoch.png' % epoch)

def plotGeneratedImages(epoch, examples=100, dim=(1, 1), figsize=(2, 2)):
    randomDim = 100
#     examples=1
    noise = np.random.normal(0, 1, size=[examples, randomDim])
    generatedImages = generator.predict(noise)
#     print(generatedImages.shape)
#     generatedImages = generatedImages*255.0 + 255.0
#     print(generatedImages.min(),generatedImages.max())
    fig = plt.figure(figsize=(30,3))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
    for i in range(10):
        ax = fig.add_subplot(1, 10, i + 1, xticks=[], yticks=[])
        ax.imshow(generatedImages[i][:,:,::-1])
    fol = 'images/gan_cnn_64x64_longrun/faces/'
    if not os.path.exists(fol):
        os.makedirs(fol)
    plt.savefig(fol+'random_{:06d}.png'.format(epoch))
    
    
def saveModels(epoch):
    fol = 'models/gan_cnn_64x64_longrun/'
    if not os.path.exists(fol):
        os.makedirs(fol)
    generator.save(fol+'dcgan_generator_epoch_%d.h5' % epoch)
    discriminator.save(fol+'dcgan_discriminator_epoch_%d.h5' % epoch)

# %% [markdown]
# # Pre-Train the discriminator

# %%
discDatagenObj_tr = discDatagen(batchSize=128,filesList=inputData)
discDatagenObj_vl = discDatagen(batchSize=128,filesList=inputData)
hist = discriminator.fit_generator(discDatagenObj_tr,epochs=200,steps_per_epoch=1,validation_data=discDatagenObj_vl,validation_steps=1,verbose=1)

df = pd.DataFrame(hist.history)
df.plot(subplots=True)
# Out:
# /home/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6906 - acc: 0.5000 - val_loss: 0.6897 - val_acc: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6864 - acc: 0.5000 - val_loss: 0.6889 - val_acc: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6843 - acc: 0.5000 - val_loss: 0.6882 - val_acc: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6828 - acc: 0.5117 - val_loss: 0.6876 - val_acc: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 83ms/step - loss: 0.6826 - acc: 0.5156 - val_loss: 0.6869 - val_acc: 0.5078
# Epoch 6/200
# 1/1 [==============================] - 0s 78ms/step - loss: 0.6811 - acc: 0.5156 - val_loss: 0.6860 - val_acc: 0.5234
# Epoch 7/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6801 - acc: 0.5273 - val_loss: 0.6851 - val_acc: 0.5469
# Epoch 8/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6802 - acc: 0.5117 - val_loss: 0.6843 - val_acc: 0.5312
# Epoch 9/200
# 1/1 [==============================] - 0s 75ms/step - loss: 0.6772 - acc: 0.5273 - val_loss: 0.6839 - val_acc: 0.5820
# Epoch 10/200
# 1/1 [==============================] - 0s 75ms/step - loss: 0.6740 - acc: 0.5234 - val_loss: 0.6840 - val_acc: 0.5781
# Epoch 11/200
# 1/1 [==============================] - 0s 76ms/step - loss: 0.6754 - acc: 0.5156 - val_loss: 0.6825 - val_acc: 0.6133
# Epoch 12/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6749 - acc: 0.5312 - val_loss: 0.6819 - val_acc: 0.6602
# Epoch 13/200
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6729 - acc: 0.5508 - val_loss: 0.6812 - val_acc: 0.6133
# Epoch 14/200
# 1/1 [==============================] - 0s 85ms/step - loss: 0.6721 - acc: 0.5586 - val_loss: 0.6808 - val_acc: 0.6680
# Epoch 15/200
# 1/1 [==============================] - 0s 76ms/step - loss: 0.6713 - acc: 0.5312 - val_loss: 0.6796 - val_acc: 0.6484
# Epoch 16/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6703 - acc: 0.5508 - val_loss: 0.6790 - val_acc: 0.6719
# Epoch 17/200
# 1/1 [==============================] - 0s 79ms/step - loss: 0.6678 - acc: 0.5781 - val_loss: 0.6786 - val_acc: 0.7031
# Epoch 18/200
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6646 - acc: 0.5859 - val_loss: 0.6778 - val_acc: 0.7188
# Epoch 19/200
# 1/1 [==============================] - 0s 88ms/step - loss: 0.6653 - acc: 0.5859 - val_loss: 0.6771 - val_acc: 0.7461
# Epoch 20/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6621 - acc: 0.6016 - val_loss: 0.6762 - val_acc: 0.6953
# Epoch 21/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6615 - acc: 0.6016 - val_loss: 0.6762 - val_acc: 0.7734
# Epoch 22/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6585 - acc: 0.6367 - val_loss: 0.6743 - val_acc: 0.7695
# Epoch 23/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6595 - acc: 0.6406 - val_loss: 0.6742 - val_acc: 0.7422
# Epoch 24/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.6568 - acc: 0.6250 - val_loss: 0.6737 - val_acc: 0.7617
# Epoch 25/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6578 - acc: 0.5938 - val_loss: 0.6725 - val_acc: 0.7852
# Epoch 26/200
# 1/1 [==============================] - 0s 126ms/step - loss: 0.6577 - acc: 0.6602 - val_loss: 0.6725 - val_acc: 0.7773
# Epoch 27/200
# 1/1 [==============================] - 0s 121ms/step - loss: 0.6544 - acc: 0.6641 - val_loss: 0.6702 - val_acc: 0.7539
# Epoch 28/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.6532 - acc: 0.6289 - val_loss: 0.6706 - val_acc: 0.8281
# Epoch 29/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.6534 - acc: 0.6211 - val_loss: 0.6706 - val_acc: 0.7891
# Epoch 30/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.6500 - acc: 0.6484 - val_loss: 0.6695 - val_acc: 0.8477
# Epoch 31/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.6485 - acc: 0.7070 - val_loss: 0.6680 - val_acc: 0.8242
# Epoch 32/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.6444 - acc: 0.6875 - val_loss: 0.6671 - val_acc: 0.8242
# Epoch 33/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.6439 - acc: 0.6797 - val_loss: 0.6667 - val_acc: 0.8516
# Epoch 34/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.6434 - acc: 0.6562 - val_loss: 0.6658 - val_acc: 0.8477
# Epoch 35/200
# 1/1 [==============================] - 0s 126ms/step - loss: 0.6429 - acc: 0.6836 - val_loss: 0.6652 - val_acc: 0.8398
# Epoch 36/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.6425 - acc: 0.6836 - val_loss: 0.6632 - val_acc: 0.8203
# Epoch 37/200
# 1/1 [==============================] - 0s 123ms/step - loss: 0.6391 - acc: 0.7266 - val_loss: 0.6621 - val_acc: 0.8516
# Epoch 38/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.6392 - acc: 0.6914 - val_loss: 0.6618 - val_acc: 0.8828
# Epoch 39/200
# 1/1 [==============================] - 0s 126ms/step - loss: 0.6356 - acc: 0.6914 - val_loss: 0.6615 - val_acc: 0.8789
# Epoch 40/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.6333 - acc: 0.7422 - val_loss: 0.6603 - val_acc: 0.8594
# Epoch 41/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.6325 - acc: 0.7227 - val_loss: 0.6594 - val_acc: 0.8789
# Epoch 42/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.6298 - acc: 0.7344 - val_loss: 0.6583 - val_acc: 0.8984
# Epoch 43/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.6299 - acc: 0.7461 - val_loss: 0.6566 - val_acc: 0.8984
# Epoch 44/200
# 1/1 [==============================] - 0s 124ms/step - loss: 0.6258 - acc: 0.7461 - val_loss: 0.6560 - val_acc: 0.8867
# Epoch 45/200
# 1/1 [==============================] - 0s 123ms/step - loss: 0.6224 - acc: 0.7578 - val_loss: 0.6542 - val_acc: 0.9023
# Epoch 46/200
# 1/1 [==============================] - 0s 121ms/step - loss: 0.6220 - acc: 0.7852 - val_loss: 0.6540 - val_acc: 0.9141
# Epoch 47/200
# 1/1 [==============================] - 0s 132ms/step - loss: 0.6207 - acc: 0.7695 - val_loss: 0.6533 - val_acc: 0.8945
# Epoch 48/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.6206 - acc: 0.7539 - val_loss: 0.6523 - val_acc: 0.8867
# Epoch 49/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.6184 - acc: 0.7695 - val_loss: 0.6522 - val_acc: 0.8906
# Epoch 50/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.6143 - acc: 0.7773 - val_loss: 0.6506 - val_acc: 0.9180
# Epoch 51/200
# 1/1 [==============================] - 0s 112ms/step - loss: 0.6131 - acc: 0.7656 - val_loss: 0.6486 - val_acc: 0.9414
# Epoch 52/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.6026 - acc: 0.8203 - val_loss: 0.6486 - val_acc: 0.9141
# Epoch 53/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.6105 - acc: 0.7734 - val_loss: 0.6446 - val_acc: 0.9414
# Epoch 54/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.6060 - acc: 0.8242 - val_loss: 0.6458 - val_acc: 0.9141
# Epoch 55/200
# 1/1 [==============================] - 0s 124ms/step - loss: 0.5991 - acc: 0.8281 - val_loss: 0.6430 - val_acc: 0.9336
# Epoch 56/200
# 1/1 [==============================] - 0s 144ms/step - loss: 0.5984 - acc: 0.8164 - val_loss: 0.6405 - val_acc: 0.9297
# Epoch 57/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.6024 - acc: 0.8008 - val_loss: 0.6397 - val_acc: 0.9297
# Epoch 58/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.5953 - acc: 0.8438 - val_loss: 0.6390 - val_acc: 0.9258
# Epoch 59/200
# 1/1 [==============================] - 0s 126ms/step - loss: 0.5931 - acc: 0.8789 - val_loss: 0.6390 - val_acc: 0.9297
# Epoch 60/200
# 1/1 [==============================] - 0s 126ms/step - loss: 0.5920 - acc: 0.8086 - val_loss: 0.6376 - val_acc: 0.9141
# Epoch 61/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.5871 - acc: 0.8711 - val_loss: 0.6342 - val_acc: 0.9570
# Epoch 62/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5850 - acc: 0.8359 - val_loss: 0.6347 - val_acc: 0.9258
# Epoch 63/200
# 1/1 [==============================] - 0s 126ms/step - loss: 0.5802 - acc: 0.8906 - val_loss: 0.6318 - val_acc: 0.9062
# Epoch 64/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5787 - acc: 0.8555 - val_loss: 0.6292 - val_acc: 0.9297
# Epoch 65/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.5761 - acc: 0.8633 - val_loss: 0.6284 - val_acc: 0.9219
# Epoch 66/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.5710 - acc: 0.8594 - val_loss: 0.6275 - val_acc: 0.9102
# Epoch 67/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.5701 - acc: 0.9062 - val_loss: 0.6224 - val_acc: 0.9492
# Epoch 68/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5688 - acc: 0.7930 - val_loss: 0.6230 - val_acc: 0.9023
# Epoch 69/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.5625 - acc: 0.9102 - val_loss: 0.6161 - val_acc: 0.9648
# Epoch 70/200
# 1/1 [==============================] - 0s 150ms/step - loss: 0.5567 - acc: 0.8086 - val_loss: 0.6180 - val_acc: 0.9062
# Epoch 71/200
# 1/1 [==============================] - 0s 144ms/step - loss: 0.5566 - acc: 0.9219 - val_loss: 0.6108 - val_acc: 0.9609
# Epoch 72/200
# 1/1 [==============================] - 0s 165ms/step - loss: 0.5532 - acc: 0.8281 - val_loss: 0.6197 - val_acc: 0.8164
# Epoch 73/200
# 1/1 [==============================] - 0s 132ms/step - loss: 0.5515 - acc: 0.9102 - val_loss: 0.6059 - val_acc: 0.9648
# Epoch 74/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.5506 - acc: 0.6914 - val_loss: 0.6212 - val_acc: 0.7344
# Epoch 75/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.5524 - acc: 0.8555 - val_loss: 0.6005 - val_acc: 0.8633
# Epoch 76/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.5619 - acc: 0.5234 - val_loss: 0.6389 - val_acc: 0.5586
# Epoch 77/200
# 1/1 [==============================] - 0s 137ms/step - loss: 0.5927 - acc: 0.6250 - val_loss: 0.6041 - val_acc: 0.5117
# Epoch 78/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.6216 - acc: 0.5000 - val_loss: 0.6665 - val_acc: 0.5156
# Epoch 79/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.6577 - acc: 0.5312 - val_loss: 0.6000 - val_acc: 0.7109
# Epoch 80/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5773 - acc: 0.5039 - val_loss: 0.6321 - val_acc: 0.6172
# Epoch 81/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5814 - acc: 0.7188 - val_loss: 0.5933 - val_acc: 0.8477
# Epoch 82/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.5610 - acc: 0.5078 - val_loss: 0.6248 - val_acc: 0.6328
# Epoch 83/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5612 - acc: 0.7695 - val_loss: 0.5886 - val_acc: 0.8945
# Epoch 84/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5477 - acc: 0.5156 - val_loss: 0.6307 - val_acc: 0.6016
# Epoch 85/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.5665 - acc: 0.7148 - val_loss: 0.5872 - val_acc: 0.8359
# Epoch 86/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.5588 - acc: 0.5117 - val_loss: 0.6274 - val_acc: 0.5977
# Epoch 87/200
# 1/1 [==============================] - 0s 126ms/step - loss: 0.5668 - acc: 0.7266 - val_loss: 0.5805 - val_acc: 0.8281
# Epoch 88/200
# 1/1 [==============================] - 0s 143ms/step - loss: 0.5535 - acc: 0.5039 - val_loss: 0.6340 - val_acc: 0.5469
# Epoch 89/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.5730 - acc: 0.6797 - val_loss: 0.5792 - val_acc: 0.7812
# Epoch 90/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.5612 - acc: 0.5039 - val_loss: 0.6258 - val_acc: 0.5898
# Epoch 91/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.5741 - acc: 0.7031 - val_loss: 0.5760 - val_acc: 0.8672
# Epoch 92/200
# 1/1 [==============================] - 0s 132ms/step - loss: 0.5460 - acc: 0.5078 - val_loss: 0.6213 - val_acc: 0.5703
# Epoch 93/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.5541 - acc: 0.7812 - val_loss: 0.5737 - val_acc: 0.9727
# Epoch 94/200
# 1/1 [==============================] - 0s 140ms/step - loss: 0.5237 - acc: 0.5586 - val_loss: 0.6098 - val_acc: 0.6641
# Epoch 95/200
# 1/1 [==============================] - 0s 121ms/step - loss: 0.5358 - acc: 0.7891 - val_loss: 0.5683 - val_acc: 0.9023
# Epoch 96/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.5352 - acc: 0.5156 - val_loss: 0.6235 - val_acc: 0.5625
# Epoch 97/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.5728 - acc: 0.6680 - val_loss: 0.5653 - val_acc: 0.8672
# Epoch 98/200
# 1/1 [==============================] - 0s 149ms/step - loss: 0.5408 - acc: 0.5039 - val_loss: 0.6250 - val_acc: 0.5703
# Epoch 99/200
# 1/1 [==============================] - 0s 137ms/step - loss: 0.5696 - acc: 0.6836 - val_loss: 0.5640 - val_acc: 0.9453
# Epoch 100/200
# 1/1 [==============================] - 0s 148ms/step - loss: 0.5206 - acc: 0.5586 - val_loss: 0.6105 - val_acc: 0.6445
# Epoch 101/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5318 - acc: 0.8125 - val_loss: 0.5567 - val_acc: 0.9648
# Epoch 102/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5108 - acc: 0.5586 - val_loss: 0.6162 - val_acc: 0.6133
# Epoch 103/200
# 1/1 [==============================] - 0s 124ms/step - loss: 0.5445 - acc: 0.7539 - val_loss: 0.5529 - val_acc: 0.9453
# Epoch 104/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.5141 - acc: 0.5391 - val_loss: 0.6141 - val_acc: 0.6055
# Epoch 105/200
# 1/1 [==============================] - 0s 139ms/step - loss: 0.5312 - acc: 0.7773 - val_loss: 0.5500 - val_acc: 0.9258
# Epoch 106/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.5196 - acc: 0.5117 - val_loss: 0.6262 - val_acc: 0.5625
# Epoch 107/200
# 1/1 [==============================] - 0s 123ms/step - loss: 0.5910 - acc: 0.6289 - val_loss: 0.5457 - val_acc: 0.9258
# Epoch 108/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.5186 - acc: 0.5078 - val_loss: 0.6235 - val_acc: 0.5664
# Epoch 109/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.5396 - acc: 0.7344 - val_loss: 0.5431 - val_acc: 0.9883
# Epoch 110/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.4811 - acc: 0.6641 - val_loss: 0.5964 - val_acc: 0.6758
# Epoch 111/200
# 1/1 [==============================] - 0s 123ms/step - loss: 0.5029 - acc: 0.8477 - val_loss: 0.5374 - val_acc: 0.9844
# Epoch 112/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.4821 - acc: 0.6562 - val_loss: 0.5961 - val_acc: 0.6641
# Epoch 113/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.5083 - acc: 0.8359 - val_loss: 0.5339 - val_acc: 0.9883
# Epoch 114/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.4832 - acc: 0.5703 - val_loss: 0.6246 - val_acc: 0.5820
# Epoch 115/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.5473 - acc: 0.6836 - val_loss: 0.5283 - val_acc: 0.9922
# Epoch 116/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.4758 - acc: 0.6094 - val_loss: 0.6074 - val_acc: 0.6250
# Epoch 117/200
# 1/1 [==============================] - 0s 124ms/step - loss: 0.5101 - acc: 0.8086 - val_loss: 0.5251 - val_acc: 0.9922
# Epoch 118/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.4615 - acc: 0.6641 - val_loss: 0.5950 - val_acc: 0.6523
# Epoch 119/200
# 1/1 [==============================] - 0s 126ms/step - loss: 0.5098 - acc: 0.7578 - val_loss: 0.5143 - val_acc: 0.9922
# Epoch 120/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.4806 - acc: 0.5625 - val_loss: 0.6115 - val_acc: 0.5977
# Epoch 121/200
# 1/1 [==============================] - 0s 137ms/step - loss: 0.5171 - acc: 0.7617 - val_loss: 0.5117 - val_acc: 0.9961
# Epoch 122/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.4526 - acc: 0.6836 - val_loss: 0.5701 - val_acc: 0.7500
# Epoch 123/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.4690 - acc: 0.8867 - val_loss: 0.5039 - val_acc: 0.9922
# Epoch 124/200
# 1/1 [==============================] - 0s 135ms/step - loss: 0.4528 - acc: 0.7031 - val_loss: 0.5911 - val_acc: 0.6367
# Epoch 125/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.4952 - acc: 0.8008 - val_loss: 0.5038 - val_acc: 0.9609
# Epoch 126/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.4856 - acc: 0.5469 - val_loss: 0.6378 - val_acc: 0.5312
# Epoch 127/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.5823 - acc: 0.6211 - val_loss: 0.5075 - val_acc: 0.9961
# Epoch 128/200
# 1/1 [==============================] - 0s 145ms/step - loss: 0.4261 - acc: 0.8242 - val_loss: 0.5605 - val_acc: 0.7852
# Epoch 129/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.4181 - acc: 0.9570 - val_loss: 0.4925 - val_acc: 0.9961
# Epoch 130/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.4086 - acc: 0.8672 - val_loss: 0.5690 - val_acc: 0.7188
# Epoch 131/200
# 1/1 [==============================] - 0s 110ms/step - loss: 0.4296 - acc: 0.8945 - val_loss: 0.4865 - val_acc: 0.9883
# Epoch 132/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.4389 - acc: 0.6680 - val_loss: 0.6299 - val_acc: 0.5312
# Epoch 133/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.5753 - acc: 0.6562 - val_loss: 0.4791 - val_acc: 0.9961
# Epoch 134/200
# 1/1 [==============================] - 0s 132ms/step - loss: 0.4370 - acc: 0.6875 - val_loss: 0.5818 - val_acc: 0.6562
# Epoch 135/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.4689 - acc: 0.8320 - val_loss: 0.4749 - val_acc: 0.9883
# Epoch 136/200
# 1/1 [==============================] - 0s 144ms/step - loss: 0.4465 - acc: 0.6406 - val_loss: 0.6190 - val_acc: 0.5703
# Epoch 137/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.5235 - acc: 0.7227 - val_loss: 0.4824 - val_acc: 0.9922
# Epoch 138/200
# 1/1 [==============================] - 0s 153ms/step - loss: 0.3948 - acc: 0.8906 - val_loss: 0.5285 - val_acc: 0.8477
# Epoch 139/200
# 1/1 [==============================] - 0s 149ms/step - loss: 0.3839 - acc: 0.9531 - val_loss: 0.4575 - val_acc: 0.9844
# Epoch 140/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.3807 - acc: 0.8984 - val_loss: 0.5530 - val_acc: 0.7109
# Epoch 141/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.4041 - acc: 0.9062 - val_loss: 0.4589 - val_acc: 0.9922
# Epoch 142/200
# 1/1 [==============================] - 0s 146ms/step - loss: 0.4448 - acc: 0.5742 - val_loss: 0.6658 - val_acc: 0.5117
# Epoch 143/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.6491 - acc: 0.5586 - val_loss: 0.4833 - val_acc: 0.9883
# Epoch 144/200
# 1/1 [==============================] - 0s 137ms/step - loss: 0.3742 - acc: 0.9531 - val_loss: 0.5080 - val_acc: 0.8828
# Epoch 145/200
# 1/1 [==============================] - 0s 147ms/step - loss: 0.3611 - acc: 0.9883 - val_loss: 0.4654 - val_acc: 0.9688
# Epoch 146/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.3382 - acc: 0.9805 - val_loss: 0.5074 - val_acc: 0.8516
# Epoch 147/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.3441 - acc: 0.9531 - val_loss: 0.4398 - val_acc: 0.9961
# Epoch 148/200
# 1/1 [==============================] - 0s 140ms/step - loss: 0.3640 - acc: 0.8789 - val_loss: 0.6220 - val_acc: 0.5547
# Epoch 149/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.5281 - acc: 0.6758 - val_loss: 0.4408 - val_acc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 155ms/step - loss: 0.4084 - acc: 0.6992 - val_loss: 0.6024 - val_acc: 0.6133
# Epoch 151/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.5390 - acc: 0.7266 - val_loss: 0.4377 - val_acc: 0.9961
# Epoch 152/200
# 1/1 [==============================] - 0s 143ms/step - loss: 0.3723 - acc: 0.8320 - val_loss: 0.5438 - val_acc: 0.7422
# Epoch 153/200
# 1/1 [==============================] - 0s 126ms/step - loss: 0.3764 - acc: 0.9141 - val_loss: 0.4280 - val_acc: 0.9961
# Epoch 154/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.3480 - acc: 0.8906 - val_loss: 0.5312 - val_acc: 0.7773
# Epoch 155/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.3715 - acc: 0.9062 - val_loss: 0.4108 - val_acc: 0.9961
# Epoch 156/200
# 1/1 [==============================] - 0s 145ms/step - loss: 0.3744 - acc: 0.8125 - val_loss: 0.5887 - val_acc: 0.6016
# Epoch 157/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.4720 - acc: 0.7773 - val_loss: 0.4120 - val_acc: 0.9883
# Epoch 158/200
# 1/1 [==============================] - 0s 132ms/step - loss: 0.3331 - acc: 0.9219 - val_loss: 0.5242 - val_acc: 0.7656
# Epoch 159/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.3595 - acc: 0.9219 - val_loss: 0.4108 - val_acc: 0.9922
# Epoch 160/200
# 1/1 [==============================] - 0s 132ms/step - loss: 0.3289 - acc: 0.9023 - val_loss: 0.5531 - val_acc: 0.7070
# Epoch 161/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.4400 - acc: 0.7891 - val_loss: 0.4010 - val_acc: 0.9961
# Epoch 162/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.3764 - acc: 0.7734 - val_loss: 0.6059 - val_acc: 0.5898
# Epoch 163/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.4605 - acc: 0.7734 - val_loss: 0.4054 - val_acc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 132ms/step - loss: 0.3087 - acc: 0.9531 - val_loss: 0.4700 - val_acc: 0.8906
# Epoch 165/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.2939 - acc: 0.9766 - val_loss: 0.3886 - val_acc: 0.9922
# Epoch 166/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.2868 - acc: 0.9688 - val_loss: 0.5181 - val_acc: 0.7695
# Epoch 167/200
# 1/1 [==============================] - 0s 144ms/step - loss: 0.3277 - acc: 0.9180 - val_loss: 0.3751 - val_acc: 0.9961
# Epoch 168/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.3712 - acc: 0.8086 - val_loss: 0.6599 - val_acc: 0.5234
# Epoch 169/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.5603 - acc: 0.6680 - val_loss: 0.4081 - val_acc: 0.9922
# Epoch 170/200
# 1/1 [==============================] - 0s 146ms/step - loss: 0.2944 - acc: 0.9883 - val_loss: 0.4359 - val_acc: 0.9492
# Epoch 171/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.2637 - acc: 0.9883 - val_loss: 0.3881 - val_acc: 0.9844
# Epoch 172/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.2364 - acc: 0.9961 - val_loss: 0.4145 - val_acc: 0.9570
# Epoch 173/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.2527 - acc: 0.9805 - val_loss: 0.3593 - val_acc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 135ms/step - loss: 0.2829 - acc: 0.9570 - val_loss: 0.5694 - val_acc: 0.6250
# Epoch 175/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.4209 - acc: 0.8125 - val_loss: 0.3562 - val_acc: 0.9961
# Epoch 176/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.3755 - acc: 0.7734 - val_loss: 0.6619 - val_acc: 0.5469
# Epoch 177/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.5625 - acc: 0.6328 - val_loss: 0.3862 - val_acc: 0.9844
# Epoch 178/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.2703 - acc: 0.9922 - val_loss: 0.4225 - val_acc: 0.9570
# Epoch 179/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.2295 - acc: 0.9961 - val_loss: 0.3888 - val_acc: 0.9688
# Epoch 180/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.2276 - acc: 0.9961 - val_loss: 0.3778 - val_acc: 0.9570
# Epoch 181/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.2150 - acc: 0.9844 - val_loss: 0.3618 - val_acc: 0.9688
# Epoch 182/200
# 1/1 [==============================] - 0s 132ms/step - loss: 0.2062 - acc: 0.9961 - val_loss: 0.3720 - val_acc: 0.9531
# Epoch 183/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.1890 - acc: 0.9883 - val_loss: 0.3743 - val_acc: 0.9609
# Epoch 184/200
# 1/1 [==============================] - 0s 140ms/step - loss: 0.1866 - acc: 0.9844 - val_loss: 0.3472 - val_acc: 0.9922
# Epoch 185/200
# 1/1 [==============================] - 0s 135ms/step - loss: 0.1773 - acc: 0.9883 - val_loss: 0.3833 - val_acc: 0.9219
# Epoch 186/200
# 1/1 [==============================] - 0s 139ms/step - loss: 0.1957 - acc: 0.9688 - val_loss: 0.2985 - val_acc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.2946 - acc: 0.8984 - val_loss: 0.7896 - val_acc: 0.5000
# Epoch 188/200
# 1/1 [==============================] - 0s 163ms/step - loss: 0.9184 - acc: 0.5352 - val_loss: 0.3482 - val_acc: 0.9883
# Epoch 189/200
# 1/1 [==============================] - 0s 126ms/step - loss: 0.2724 - acc: 0.9688 - val_loss: 0.4660 - val_acc: 0.8281
# Epoch 190/200
# 1/1 [==============================] - 0s 146ms/step - loss: 0.2588 - acc: 0.9531 - val_loss: 0.3344 - val_acc: 0.9883
# Epoch 191/200
# 1/1 [==============================] - 0s 135ms/step - loss: 0.2162 - acc: 1.0000 - val_loss: 0.4291 - val_acc: 0.8555
# Epoch 192/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.2173 - acc: 0.9727 - val_loss: 0.3170 - val_acc: 0.9922
# Epoch 193/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.2114 - acc: 0.9883 - val_loss: 0.4799 - val_acc: 0.7695
# Epoch 194/200
# 1/1 [==============================] - 0s 132ms/step - loss: 0.2885 - acc: 0.9102 - val_loss: 0.2874 - val_acc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 121ms/step - loss: 0.2850 - acc: 0.9102 - val_loss: 0.6457 - val_acc: 0.5469
# Epoch 196/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.5252 - acc: 0.7031 - val_loss: 0.3162 - val_acc: 0.9961
# Epoch 197/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.2679 - acc: 0.9375 - val_loss: 0.4623 - val_acc: 0.8047
# Epoch 198/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.2444 - acc: 0.9531 - val_loss: 0.2983 - val_acc: 0.9961
# Epoch 199/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.1877 - acc: 1.0000 - val_loss: 0.3621 - val_acc: 0.9375
# Epoch 200/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.1823 - acc: 0.9922 - val_loss: 0.3011 - val_acc: 0.9844
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6904e60f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa6904b3390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa69045c4a8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa6904075c0>],
#       dtype=object)

# %% [markdown]
# # Training Code

# %%
def train(epochs=1, batchSize=128, number_of_steps = 10):
    
    print ('Epochs:', epochs)
    print ('Batch size:', batchSize)
    print ('steps per epoch:',number_of_steps)
    datagenObj = datagen(batchSize,inputData)
    counter = 0
    for e in tqdm(range(1, epochs+1)):
        for step in range(number_of_steps):
            # Get a random set of input noise and images
            noise = np.random.normal(0, 1, size=[batchSize, randomDim])
            realImages = next(datagenObj)
            generatedImages = generator.predict(noise)
#             print(generatedImages.shape)
#             print(imageBatch.shape)
            X = np.concatenate([realImages, generatedImages])
            yDis = np.ones(2*batchSize)
            yDis[:batchSize] = 0 # real images 0 fake 1# normal training
            yDis = to_categorical(yDis,num_classes=2)
            # Train discriminator
            discriminator.trainable = True
            dloss = discriminator.train_on_batch(X, yDis)
#             print(dloss)
            # Train generator
            noise = np.random.normal(0, 1, size=[batchSize, randomDim])
            yGen = np.zeros(batchSize) # pose generated images as real # imposter
            yGen = to_categorical(yGen,num_classes=2)
            discriminator.trainable = False
            gloss = gan.train_on_batch(noise, yGen)
#             print(gloss)
#             counter+=1
            
            tensorboard.on_epoch_end(e, {"D_acc":dloss[1],"D_loss":dloss[0],"G_acc":gloss[1],"G_loss":gloss[0]})
        # Store loss of most recent batch from this epoch
        dLosses.append(dloss)
        gLosses.append(gloss)

        if e == 1 or e % 1000 == 0:
            plotGeneratedImages(e)
            saveModels(e)
    tensorboard.on_train_end(None)

    # Plot losses from every epoch
    plotLoss(e)

if __name__ == '__main__':
    print("")
    train(100000, 128, 1)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Epochs: 100000
# Batch size: 128
# steps per epoch: 1
#   2%|▏         | 2039/100000 [12:17<9:50:20,  2.77it/s]

# %%
examples=100
dim=(1, 1)
figsize=(2, 2)
noise = np.random.normal(0, 1, size=[examples, randomDim])
generatedImages = generator.predict(noise)
#     generatedImages = generatedImages*255.0 + 255.0
#     print(generatedImages.min(),generatedImages.max())
fig = plt.figure(figsize=(60,6))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(10):
    ax = fig.add_subplot(1, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(generatedImages[i][:,:,::-1])
